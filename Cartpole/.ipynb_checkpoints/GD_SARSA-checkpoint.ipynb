# %% [markdown]
# #### Gradient Descent SARSA algorithm demonstration using Cart-Pole env from OpenAI Gym

# %%
import gym
import collections
import copy
import numpy as np
import matplotlib.pyplot as plt
import time
import keras
from keras.models import Sequential
from keras.layers import Dense, normalization
from keras.optimizers import SGD,RMSprop,Nadam
# Out:
# Using TensorFlow backend.

# %%
class Agent(object):
    def __init__(self, env):
        self.env = env
        self.memory = collections.deque(maxlen=5000)
        self.epsilon = 0.6
        self.epsilonDecayFactor = 0.99
        self.epsilonMin = 0.1
        self.gamma = 0.9                             # discount factor for Q-learning
        self.lr = 0.001                              # Learning Rate
        self.replayBatchSize = 100                 # Number of memories to use for training
        self.model = self.build_model()
        
        
    def build_model(self):
        model = keras.models.Sequential()
        model.add(Dense(64, input_dim=4, activation='tanh', init='he_uniform'))
        model.add(Dense(128, activation='tanh', init='he_uniform'))
        model.add(Dense(64, activation='tanh', init='he_uniform'))
        model.add(Dense(2, activation='linear', init='he_uniform'))
        model.compile(loss='mse', optimizer=RMSprop(lr=self.lr))
        return model
        
    def choose_action(self, state):
        if (np.random.rand() > self.epsilon):
            action_values = self.model.predict(state)[0] #[Q(s,a1),Q(s,a2)]
            return np.argmax(action_values)
        else:
            return self.env.action_space.sample()
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
    
    def replay(self):
        memorySampleIndices = np.random.choice(len(self.memory),
                                               size=min(len(self.memory),self.replayBatchSize),
                                               replace=False)
        for i in memorySampleIndices:
            state, action, reward, next_state, done = self.memory[i]             # s, ai, r, s_next 
            Q_estimate = self.model.predict(np.array(state).reshape(1,4))[0]    # [Q(s,a1), Q(s,a2)]
            if not done:
                next_Qs = self.model.predict(np.array(next_state).reshape(1,4))[0]  # [Q_next(s_next,a1), Q_next(s_next,a2)]
                target = reward + self.gamma*max(next_Qs)                           # This is what the Q(s,ai) should be (new estimate!)
            else:
                target = reward
            Q_estimate[action] = target                                         # Updating the Q_estimate to use the better estimate for action ai
            # Update the model parameters to fit the change
            self.model.fit(np.array(state).reshape(1,4),
                           np.array(Q_estimate).reshape(1,2),
                           nb_epoch=1,
                           verbose=False)
        #decrese the epsilon after each episode
        self.epsilon = self.epsilonDecayFactor * self.epsilon if self.epsilon > self.epsilonMin else self.epsilon

# %%
#train
env = gym.make('CartPole-v0')
agent = Agent(env=env)
# agent.model.load_weights("./100000_iter_weights.h5")
for episode in range(500):
    state = env.reset()
    for t in range(5000): 
#         env.render()
        action = agent.choose_action(np.array(state).reshape(1,4))  # Choose an action
        next_state, reward, done, info = env.step(action)           # Observe next_state, reward
        reward = -1000/t if done else reward+t                          # heavily penalize the failing reward
        agent.remember(state, action, reward, next_state, done)     # remember SARS + done
        state = copy.deepcopy(next_state)                           # state = next_state
        if done:
            print("Episode {} finished after {} timesteps. memory size: {}. epsilon: {}".format(episode,t+1, len(agent.memory), agent.epsilon))
            break
    if(episode%50 == 0):
        print("Saving the model...\n")
        agent.model.save_weights("./model_weights.h5")
    agent.replay()
env.render(close=True)
# Out:
# [2017-02-15 12:49:47,988] Making new env: CartPole-v0
timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 467 finished after 59 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 468 finished after 74 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 469 finished after 42 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 470 finished after 46 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 471 finished after 89 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 472 finished after 133 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 473 finished after 76 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 474 finished after 97 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 475 finished after 83 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 476 finished after 174 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 477 finished after 99 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 478 finished after 81 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 479 finished after 51 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 480 finished after 45 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 481 finished after 64 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 482 finished after 51 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 483 finished after 96 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 484 finished after 110 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 485 finished after 85 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 486 finished after 130 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 487 finished after 101 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 488 finished after 89 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 489 finished after 140 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 490 finished after 211 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 491 finished after 132 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 492 finished after 89 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 493 finished after 160 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 494 finished after 60 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 495 finished after 76 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 496 finished after 83 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 497 finished after 224 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 498 finished after 124 timesteps. memory size: 5000. epsilon: 0.0992775573988
# Episode 499 finished after 72 timesteps. memory size: 5000. epsilon: 0.0992775573988

# %%
#test
env = gym.make('CartPole-v0')
agent = Agent(env=env)
agent.epsilon = 0.0 # No exploration for testing
agent.model.load_weights("./300_iter_weights.h5")
for episode in range(51):
    state = env.reset()
    for t in range(5000): 
        env.render()
        action = agent.choose_action(np.array(state).reshape(1,4))  # Choose an action
        next_state, reward, done, info = env.step(action)           # Observe next_state, reward
        state = copy.deepcopy(next_state)                           # state = next_state
        if done:
            print("Episode {} finished after {} timesteps. memory size: {}. epsilon: {}".format(episode,t+1, len(agent.memory), agent.epsilon))
            break
env.render(close=True)
# Out:
# [2017-02-15 12:54:02,929] Making new env: CartPole-v0
# Episode 0 finished after 71 timesteps. memory size: 0. epsilon: 0.0
# Episode 1 finished after 112 timesteps. memory size: 0. epsilon: 0.0
# Episode 2 finished after 143 timesteps. memory size: 0. epsilon: 0.0
# Episode 3 finished after 107 timesteps. memory size: 0. epsilon: 0.0
# Episode 4 finished after 112 timesteps. memory size: 0. epsilon: 0.0
# Episode 5 finished after 58 timesteps. memory size: 0. epsilon: 0.0
# Episode 6 finished after 58 timesteps. memory size: 0. epsilon: 0.0
# Episode 7 finished after 75 timesteps. memory size: 0. epsilon: 0.0
# Episode 8 finished after 57 timesteps. memory size: 0. epsilon: 0.0
# Episode 9 finished after 138 timesteps. memory size: 0. epsilon: 0.0
# Episode 10 finished after 144 timesteps. memory size: 0. epsilon: 0.0
# Episode 11 finished after 124 timesteps. memory size: 0. epsilon: 0.0
# Episode 12 finished after 73 timesteps. memory size: 0. epsilon: 0.0
# Episode 13 finished after 108 timesteps. memory size: 0. epsilon: 0.0
# Episode 14 finished after 50 timesteps. memory size: 0. epsilon: 0.0
# Episode 15 finished after 222 timesteps. memory size: 0. epsilon: 0.0
# Episode 16 finished after 127 timesteps. memory size: 0. epsilon: 0.0
# Episode 17 finished after 67 timesteps. memory size: 0. epsilon: 0.0
# Episode 18 finished after 88 timesteps. memory size: 0. epsilon: 0.0
# Episode 19 finished after 78 timesteps. memory size: 0. epsilon: 0.0
# Episode 20 finished after 119 timesteps. memory size: 0. epsilon: 0.0
# Episode 21 finished after 86 timesteps. memory size: 0. epsilon: 0.0
# Episode 22 finished after 108 timesteps. memory size: 0. epsilon: 0.0
# Episode 23 finished after 82 timesteps. memory size: 0. epsilon: 0.0
# Episode 24 finished after 122 timesteps. memory size: 0. epsilon: 0.0
# Episode 25 finished after 103 timesteps. memory size: 0. epsilon: 0.0
# Episode 26 finished after 115 timesteps. memory size: 0. epsilon: 0.0
# Episode 27 finished after 62 timesteps. memory size: 0. epsilon: 0.0
# Episode 28 finished after 63 timesteps. memory size: 0. epsilon: 0.0
# Episode 29 finished after 106 timesteps. memory size: 0. epsilon: 0.0
# Episode 30 finished after 199 timesteps. memory size: 0. epsilon: 0.0
# Episode 31 finished after 59 timesteps. memory size: 0. epsilon: 0.0
# Episode 32 finished after 52 timesteps. memory size: 0. epsilon: 0.0
# Episode 33 finished after 79 timesteps. memory size: 0. epsilon: 0.0
# Episode 34 finished after 61 timesteps. memory size: 0. epsilon: 0.0
# Episode 35 finished after 110 timesteps. memory size: 0. epsilon: 0.0
# Episode 36 finished after 99 timesteps. memory size: 0. epsilon: 0.0
# Episode 37 finished after 93 timesteps. memory size: 0. epsilon: 0.0
# Episode 38 finished after 81 timesteps. memory size: 0. epsilon: 0.0
# Episode 39 finished after 84 timesteps. memory size: 0. epsilon: 0.0
# Episode 40 finished after 85 timesteps. memory size: 0. epsilon: 0.0
# Episode 41 finished after 70 timesteps. memory size: 0. epsilon: 0.0
# Episode 42 finished after 124 timesteps. memory size: 0. epsilon: 0.0
# Episode 43 finished after 127 timesteps. memory size: 0. epsilon: 0.0
# Episode 44 finished after 89 timesteps. memory size: 0. epsilon: 0.0
# Episode 45 finished after 60 timesteps. memory size: 0. epsilon: 0.0
# Episode 46 finished after 90 timesteps. memory size: 0. epsilon: 0.0
# Episode 47 finished after 125 timesteps. memory size: 0. epsilon: 0.0
# Episode 48 finished after 99 timesteps. memory size: 0. epsilon: 0.0
# Episode 49 finished after 56 timesteps. memory size: 0. epsilon: 0.0
# Episode 50 finished after 76 timesteps. memory size: 0. epsilon: 0.0
# Episode 51 finished after 56 timesteps. memory size: 0. epsilon: 0.0
# Episode 52 finished after 126 timesteps. memory size: 0. epsilon: 0.0
# Episode 53 finished after 88 timesteps. memory size: 0. epsilon: 0.0
# Episode 54 finished after 112 timesteps. memory size: 0. epsilon: 0.0
# Episode 55 finished after 114 timesteps. memory size: 0. epsilon: 0.0
# Episode 56 finished after 87 timesteps. memory size: 0. epsilon: 0.0
# Episode 57 finished after 142 timesteps. memory size: 0. epsilon: 0.0
# Episode 58 finished after 63 timesteps. memory size: 0. epsilon: 0.0
# Episode 59 finished after 182 timesteps. memory size: 0. epsilon: 0.0
# Episode 60 finished after 76 timesteps. memory size: 0. epsilon: 0.0
# Episode 61 finished after 90 timesteps. memory size: 0. epsilon: 0.0
# Episode 62 finished after 83 timesteps. memory size: 0. epsilon: 0.0
# Episode 63 finished after 149 timesteps. memory size: 0. epsilon: 0.0
# Episode 64 finished after 73 timesteps. memory size: 0. epsilon: 0.0
# Episode 65 finished after 172 timesteps. memory size: 0. epsilon: 0.0
# Episode 66 finished after 80 timesteps. memory size: 0. epsilon: 0.0
# Episode 67 finished after 168 timesteps. memory size: 0. epsilon: 0.0
# Episode 68 finished after 147 timesteps. memory size: 0. epsilon: 0.0
# Episode 69 finished after 149 timesteps. memory size: 0. epsilon: 0.0
# Episode 70 finished after 146 timesteps. memory size: 0. epsilon: 0.0
# Episode 71 finished after 129 timesteps. memory size: 0. epsilon: 0.0
# Episode 72 finished after 105 timesteps. memory size: 0. epsilon: 0.0
# Episode 73 finished after 95 timesteps. memory size: 0. epsilon: 0.0
# Episode 74 finished after 73 timesteps. memory size: 0. epsilon: 0.0
# Episode 75 finished after 142 timesteps. memory size: 0. epsilon: 0.0
# Episode 76 finished after 102 timesteps. memory size: 0. epsilon: 0.0
# Episode 77 finished after 103 timesteps. memory size: 0. epsilon: 0.0
# Episode 78 finished after 62 timesteps. memory size: 0. epsilon: 0.0
# Episode 79 finished after 198 timesteps. memory size: 0. epsilon: 0.0
# Episode 80 finished after 53 timesteps. memory size: 0. epsilon: 0.0
# Episode 81 finished after 120 timesteps. memory size: 0. epsilon: 0.0
# Episode 82 finished after 63 timesteps. memory size: 0. epsilon: 0.0
# Episode 83 finished after 73 timesteps. memory size: 0. epsilon: 0.0
# Episode 84 finished after 80 timesteps. memory size: 0. epsilon: 0.0
# Episode 85 finished after 155 timesteps. memory size: 0. epsilon: 0.0
# Episode 86 finished after 110 timesteps. memory size: 0. epsilon: 0.0
# Episode 87 finished after 49 timesteps. memory size: 0. epsilon: 0.0
# Episode 88 finished after 158 timesteps. memory size: 0. epsilon: 0.0
# Episode 89 finished after 53 timesteps. memory size: 0. epsilon: 0.0
# Episode 90 finished after 79 timesteps. memory size: 0. epsilon: 0.0
# Episode 91 finished after 136 timesteps. memory size: 0. epsilon: 0.0
# Episode 92 finished after 78 timesteps. memory size: 0. epsilon: 0.0
# Episode 93 finished after 60 timesteps. memory size: 0. epsilon: 0.0
# Episode 94 finished after 191 timesteps. memory size: 0. epsilon: 0.0
# Episode 95 finished after 165 timesteps. memory size: 0. epsilon: 0.0
# Episode 96 finished after 122 timesteps. memory size: 0. epsilon: 0.0
# Episode 97 finished after 114 timesteps. memory size: 0. epsilon: 0.0
# Episode 98 finished after 75 timesteps. memory size: 0. epsilon: 0.0
# Episode 99 finished after 77 timesteps. memory size: 0. epsilon: 0.0
# Episode 100 finished after 48 timesteps. memory size: 0. epsilon: 0.0

# %%
# From openA1 gym

import numpy as np
import gym

env = gym.make('CartPole-v1')
for episode in range(1):
    observation = env.reset()
    for i in range(50):
        env.render()
        output_vector = np.zeros((2, 1))
        output_vector[1] = np.tanh(observation[2] + observation[3])
        print(output_vector)
        action = np.argmax(output_vector)
        observation, reward, done, _ = env.step(action)
        if done:
            break
env.render(close=True)
# Out:
# [2017-02-15 12:30:07,233] Making new env: CartPole-v1
# [[ 0.        ]
#  [ 0.05375614]]
# [[ 0.        ]
#  [-0.22563813]]
# [[ 0.        ]
#  [ 0.06651141]]
# [[ 0.        ]
#  [-0.21454871]]
# [[ 0.        ]
#  [ 0.07711924]]
# [[ 0.        ]
#  [-0.20529476]]
# [[ 0.        ]
#  [ 0.08588051]]
# [[ 0.        ]
#  [-0.19764454]]
# [[ 0.        ]
#  [ 0.09304517]]
# [[ 0.        ]
#  [-0.19140188]]
# [[ 0.        ]
#  [ 0.09881882]]
# [[ 0.        ]
#  [-0.18640325]]
# [[ 0.        ]
#  [ 0.10336839]]
# [[ 0.        ]
#  [-0.18251488]]
# [[ 0.        ]
#  [ 0.10682694]]
# [[ 0.        ]
#  [-0.17963015]]
# [[ 0.        ]
#  [ 0.10929755]]
# [[ 0.        ]
#  [-0.17766726]]
# [[ 0.        ]
#  [ 0.11085639]]
# [[ 0.        ]
#  [-0.17656736]]
# [[ 0.        ]
#  [ 0.11155516]]
# [[ 0.        ]
#  [-0.17629307]]
# [[ 0.        ]
#  [ 0.11142269]]
# [[ 0.        ]
#  [-0.17682744]]
# [[ 0.        ]
#  [ 0.11046605]]
# [[ 0.       ]
#  [-0.1781733]]
# [[ 0.        ]
#  [ 0.10867102]]
# [[ 0.       ]
#  [-0.1803531]]
# [[ 0.        ]
#  [ 0.10600193]]
# [[ 0.        ]
#  [-0.18340906]]
# [[ 0.        ]
#  [ 0.10240106]]
# [[ 0.        ]
#  [-0.18740378]]
# [[ 0.        ]
#  [ 0.09778731]]
# [[ 0.        ]
#  [-0.19242111]]
# [[ 0.        ]
#  [ 0.09205445]]
# [[ 0.        ]
#  [-0.19856748]]
# [[ 0.        ]
#  [ 0.08506864]]
# [[ 0.        ]
#  [-0.20597343]]
# [[ 0.        ]
#  [ 0.07666536]]
# [[ 0.       ]
#  [-0.2147953]]
# [[ 0.        ]
#  [ 0.06664576]]
# [[ 0.        ]
#  [-0.22521708]]
# [[ 0.        ]
#  [ 0.05477231]]
# [[ 0.        ]
#  [-0.23745201]]
# [[ 0.        ]
#  [ 0.04076403]]
# [[ 0.        ]
#  [-0.25174372]]
# [[ 0.        ]
#  [ 0.02429135]]
# [[ 0.       ]
#  [-0.2683664]]
# [[ 0.        ]
#  [ 0.00497111]]
# [[ 0.        ]
#  [-0.28762311]]

# %%
# %run cart_pole.py
# Out:
# [2017-02-14 16:48:28,019] Making new env: CartPole-v0
# Episode 0 finished after 9 timesteps. memory size: 9. epsilon: 0.1
# Saving the model...
#
# Episode 1 finished after 9 timesteps. memory size: 18. epsilon: 0.099
# Episode 2 finished after 98 timesteps. memory size: 116. epsilon: 0.09801
# Episode 3 finished after 60 timesteps. memory size: 176. epsilon: 0.0970299
# Episode 4 finished after 39 timesteps. memory size: 215. epsilon: 0.096059601
# Episode 5 finished after 10 timesteps. memory size: 225. epsilon: 0.09509900499
# Episode 6 finished after 31 timesteps. memory size: 256. epsilon: 0.0941480149401
# Episode 7 finished after 17 timesteps. memory size: 273. epsilon: 0.0932065347907
# Episode 8 finished after 29 timesteps. memory size: 302. epsilon: 0.0922744694428
# Episode 9 finished after 25 timesteps. memory size: 327. epsilon: 0.0913517247484
# Episode 10 finished after 40 timesteps. memory size: 367. epsilon: 0.0904382075009
# Episode 11 finished after 34 timesteps. memory size: 401. epsilon: 0.0895338254259
# Saving the model...
#
# Episode 51 finished after 165 timesteps. memory size: 2214. epsilon: 0.0598956006466
# Episode 52 finished after 104 timesteps. memory size: 2318. epsilon: 0.0592966446401
# Episode 53 finished after 48 timesteps. memory size: 2366. epsilon: 0.0587036781937
# Episode 54 finished after 19 timesteps. memory size: 2385. epsilon: 0.0581166414118
# Episode 55 finished after 53 timesteps. memory size: 2438. epsilon: 0.0575354749977
# Episode 56 finished after 36 timesteps. memory size: 2474. epsilon: 0.0569601202477
# Episode 57 finished after 38 timesteps. memory size: 2512. epsilon: 0.0563905190452
# Episode 58 finished after 199 timesteps. memory size: 2711. epsilon: 0.0558266138548
# Episode 59 finished after 109 timesteps. memory size: 2820. epsilon: 0.0552683477162
# Episode 60 finished after 32 timesteps. memory size: 2852. epsilon: 0.0547156642391
# Episode 61 finished after 61 timesteps. memory size: 2913. epsilon: 0.0541685075967
# Episode 62 finished after 65 timesteps. memory size: 2978. epsilon: 0.0536268225207
# Episode 63 finished after 15 timesteps. memory size: 2993. epsilon: 0.0530905542955
# Episode 64 finished after 13 timesteps. memory size: 3006. epsilon: 0.0525596487526
# Episode 65 finished after 48 timesteps. memory size: 3054. epsilon: 0.052034052265
# Episode 66 finished after 181 timesteps. memory size: 3235. epsilon: 0.0515137117424
# Episode 67 finished after 18 timesteps. memory size: 3253. epsilon: 0.050998574625
# Episode 68 finished after 15 timesteps. memory size: 3268. epsilon: 0.0504885888787
# Episode 69 finished after 20 timesteps. memory size: 3288. epsilon: 0.0499837029899
# Episode 70 finished after 24 timesteps. memory size: 3312. epsilon: 0.04948386596
# Episode 71 finished after 121 timesteps. memory size: 3433. epsilon: 0.0489890273004
# Episode 72 finished after 62 timesteps. memory size: 3495. epsilon: 0.0484991370274
# Episode 73 finished after 40 timesteps. memory size: 3535. epsilon: 0.0480141456571
# Episode 74 finished after 43 timesteps. memory size: 3578. epsilon: 0.0475340042006
# Episode 75 finished after 22 timesteps. memory size: 3600. epsilon: 0.0470586641586
# Episode 76 finished after 9 timesteps. memory size: 3609. epsilon: 0.046588077517
# Episode 77 finished after 21 timesteps. memory size: 3630. epsilon: 0.0461221967418
# Episode 78 finished after 9 timesteps. memory size: 3639. epsilon: 0.0456609747744
# Episode 79 finished after 25 timesteps. memory size: 3664. epsilon: 0.0452043650266
# Episode 80 finished after 26 timesteps. memory size: 3690. epsilon: 0.0447523213764
# Episode 81 finished after 86 timesteps. memory size: 3776. epsilon: 0.0443047981626
# Episode 82 finished after 43 timesteps. memory size: 3819. epsilon: 0.043861750181
# Episode 83 finished after 38 timesteps. memory size: 3857. epsilon: 0.0434231326792
# Episode 84 finished after 13 timesteps. memory size: 3870. epsilon: 0.0429889013524
# Episode 85 finished after 21 timesteps. memory size: 3891. epsilon: 0.0425590123389
# Episode 86 finished after 22 timesteps. memory size: 3913. epsilon: 0.0421334222155
# Episode 87 finished after 18 timesteps. memory size: 3931. epsilon: 0.0417120879933
# Episode 88 finished after 59 timesteps. memory size: 3990. epsilon: 0.0412949671134
# Episode 89 finished after 92 timesteps. memory size: 4082. epsilon: 0.0408820174423
# Episode 90 finished after 27 timesteps. memory size: 4109. epsilon: 0.0404731972678
# Episode 91 finished after 20 timesteps. memory size: 4129. epsilon: 0.0400684652952
# Episode 92 finished after 18 timesteps. memory size: 4147. epsilon: 0.0396677806422
# Episode 93 finished after 24 timesteps. memory size: 4171. epsilon: 0.0392711028358
# Episode 94 finished after 29 timesteps. memory size: 4200. epsilon: 0.0388783918074
# Episode 95 finished after 16 timesteps. memory size: 4216. epsilon: 0.0384896078893
# Episode 96 finished after 40 timesteps. memory size: 4256. epsilon: 0.0381047118105
# Episode 97 finished after 92 timesteps. memory size: 4348. epsilon: 0.0377236646924
# Episode 98 finished after 153 timesteps. memory size: 4501. epsilon: 0.0373464280454
# Episode 99 finished after 258 timesteps. memory size: 4759. epsilon: 0.036972963765
# Episode 100 finished after 28 timesteps. memory size: 4787. epsilon: 0.0366032341273
# Saving the model...
#
# Episode 101 finished after 121 timesteps. memory size: 4908. epsilon: 0.036237201786
# Episode 102 finished after 58 timesteps. memory size: 4966. epsilon: 0.0358748297682
# Episode 103 finished after 106 timesteps. memory size: 5000. epsilon: 0.0355160814705
# Episode 104 finished after 33 timesteps. memory size: 5000. epsilon: 0.0351609206558
# Episode 105 finished after 8 timesteps. memory size: 5000. epsilon: 0.0348093114492
# Episode 106 finished after 66 timesteps. memory size: 5000. epsilon: 0.0344612183348
# Episode 107 finished after 22 timesteps. memory size: 5000. epsilon: 0.0341166061514
# Episode 108 finished after 57 timesteps. memory size: 5000. epsilon: 0.0337754400899
# Episode 109 finished after 106 timesteps. memory size: 5000. epsilon: 0.033437685689
# Episode 110 finished after 99 timesteps. memory size: 5000. epsilon: 0.0331033088321
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/erfi/Documents/ML/barto/GD_SARSA/cart_pole.py in <module>()
#      86
#      87 if __name__ == "__main__":
# ---> 88     main()
#
# /Users/erfi/Documents/ML/barto/GD_SARSA/cart_pole.py in main()
#      82             print("Saving the model...\n")
#      83             agent.model.save_weights("./model_weights.h5")
# ---> 84         agent.replay()
#      85     # env.render(close=True)
#      86
#
# /Users/erfi/Documents/ML/barto/GD_SARSA/cart_pole.py in replay(self)
#      59                            np.array(Q_estimate).reshape(1,2),
#      60                            nb_epoch=1,
# ---> 61                            verbose=False)
#      62         #decrese the epsilon after each episode
#      63         self.epsilon = self.epsilonDecayFactor * self.epsilon if self.epsilon > self.epsilonMin else self.epsilon
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/keras/models.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     670                               class_weight=class_weight,
#     671                               sample_weight=sample_weight,
# --> 672                               initial_epoch=initial_epoch)
#     673
#     674     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch)
#    1190                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1191                               callback_metrics=callback_metrics,
# -> 1192                               initial_epoch=initial_epoch)
#    1193
#    1194     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#     890                 batch_logs['size'] = len(batch_ids)
#     891                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 892                 outs = f(ins_batch)
#     893                 if not isinstance(outs, list):
#     894                     outs = [outs]
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    1898         session = get_session()
#    1899         updated = session.run(self.outputs + [self.updates_op],
# -> 1900                               feed_dict=feed_dict)
#    1901         return updated[:len(self.outputs)]
#    1902
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /Users/erfi/Documents/ML/env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
